# %% [markdown]
# <a href="https://colab.research.google.com/github/fea-dev-usp/Curso-de-Python-FEA.dev/blob/main/Lista%20de%20Exerc%C3%ADcios/Lista_Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir no Colab"/></a>

# %% [markdown]
# # **Lista de Exercícios: Aula 1 - Curso de Python FEA.dev**

# %% [markdown]
# #### **Exercicio 1** - Crie um programa que funcione como um conversor de moedas simples. Peça ao usuário para digitar a quantidade de Dólares (USD) que ele possui e a cotação atual do Dólar em Reais (BRL). Converta as entradas de string para float, calcule o valor total em Reais e exiba o resultado usando f-strings, formatado com duas casas decimais.
#
# #### Exemplo de saída esperada: "Os $50.00 equivalem a R$254.50 na cotação atual."

# %%
# Comece aqui

# %% [markdown]
# #### **Exercício 2** - Retorno on Investment (ROI) é uma métrica crucial em finanças. Faça um programa que solicite ao usuário o "Valor Inicial do Investimento" e o "Valor Final do Investimento". Utilize os operadores para calcular o ROI através da fórmula: ROI = ((Valor Final - Valor Inicial) / Valor Inicial) * 100. Exiba o resultado percentual.

# %%
# Comece aqui

# %% [markdown]
# #### **Exercício 3** - Você extraiu alguns dados de um sistema antigo da corretora, mas os códigos das ações vieram fora do padrão: com espaços sobrando nas bordas e misturando letras maiúsculas e minúsculas.
#
# #### No seu código, considere que você já recebeu as seguintes variáveis:

# %%
ativo1 = "   petr4 "
ativo2 = "  iTuB4  "
ativo3 = "   VALE3  "

# Comece aqui

# %% [markdown]
# #### **Exercício 4** - imagine que você precisa dividir os dividendos de um fundo imobiliário igualmente entre um grupo de cotistas. Crie um programa que peça o "Valor total dos dividendos (R$)" e o "Número de cotistas". Use um bloco try / except para impedir que o programa quebre nas seguintes situações:
#
# #### Se o usuário digitar um texto em vez de números (ValueError).
#
# #### Se o usuário informar que o número de cotistas é 0 (ZeroDivisionError).
#
# #### Caso os dados sejam preenchidos corretamente, exiba o valor que cada cotista irá receber.

# %%
# Comece aqui
